# %%
1. What is the difference between a function and a method in Python?
 - A function is a block of reusable code that can be called by its name, and it is not tied to any specific object. You define it using the def keyword
 - A method is similar to a function, but it is associated with an object and is called on that object. Methods are functions that belong to a class
2. Explain the concept of function arguments and parameters in Python.
 - Parameters are placeholders in the function definition. They define what kind of input the function expects.
 - Arguments are the actual values you pass to the function when calling it.
3. What are the different ways to define and call a function in Python?
 Defining a function:
 - def greet(name):
    return f"Hello, {name}"
 Calling a function:
 - print(greet("Steve"))
 Using a lambda function:
 - greet = lambda name: f"Hello, {name}"
print(greet("Steve"))
4. What is the purpose of the `return` statement in a Python function?
 - The return statement sends a value back to the caller of the function. It ends the function's execution and provides the result.
 Example:
 - def add(a, b):
    return a + b
result = add(3, 4)
print(result)
5. What are iterators in Python and how do they differ from iterables?
 - A set is used instead of a list when you need to remove duplicate values automatically.
6. What is a string in Python, and how is it different from a list?
 - A string is a sequence of characters (immutable) in Python.
A list is a mutable sequence that can contain elements of different data types.
Strings are typically used for textual data, whereas lists are used for collections of items.
7. How do tuples ensure data integrity in Python?
 - Tuples are immutable, meaning their elements cannot be changed after creation. This ensures that:
    Data remains consistent and protected from accidental modification.
    They can be used as keys in dictionaries or stored in sets, unlike lists.
8. 4. What is a hash table, and how does it relate to dictionaries in Python?
 - A hash table is a data structure that maps keys to values using a hashing function to compute an index. Python dictionaries use hash tables internally to provide:
    Fast lookups, insertions, and deletions (average time complexity 𝑂(1)).
    Keys must be hashable (e.g., strings, numbers, tuples).
9. Can lists contain different data types in Python?
 - Yes, Python lists can contain elements of different data types.
10. Explain why strings are immutable in Python.
 - Strings are immutable because:
    It ensures thread safety during concurrent operations.
    It allows string objects to be interned or reused, saving memory and improving performance.
    Modifying a string requires creating a new one, preventing accidental changes.
11. What advantages do dictionaries offer over lists for certain tasks?
 - Dictionaries are preferred when:
    Data needs to be accessed by keys rather than index positions.
    The order of elements isn’t crucial.
12. Describe a scenario where using a tuple would be preferable over a list.
 - If we want to store the marks of the students then using tuple is more effective as it avoid data manipulation.
13. How do sets handle duplicate values in Python?
 - Sets automatically eliminate duplicate values. If you add a duplicate value to a set, it will be ignored.
  s = {1, 2, 3, 3}
  print(s)  # Output: {1, 2, 3}
14. For lists, in checks for the presence of a value.
    For dictionaries, in checks for the presence of a value, not the key.
      l = [1, 2, 3]
      print(1 in l)  # True

      d = {"a": 1, "b": 2}
      print("a" in d)  # True
      print(1 in d)    # False
15. Can you modify the elements of a tuple? Explain why or why not.
 - No, you cannot modify the elements of a tuple because tuples are immutable. However, if the tuple contains mutable objects (e.g., a list), the mutable object itself can be modified.
16. What is a nested dictionary, and give an example of its use case.
 - A nested dictionary is a dictionary where values are dictionaries themselves.
    students = {
    "Alice": {"math": 90, "science": 85},
    "Bob": {"math": 78, "science": 92}
        }
    print(students["Alice"]["math"])  # Output: 90
17. Describe the time complexity of accessing elements in a dictionary.
 - Accessing elements in a dictionary has an average time complexity of 𝑂(1) due to the underlying hash table.
18. In what situations are lists preferred over dictionaries?
 - Lists are preferred when:
    Data does not require a key-value structure.
    The order of elements is important.
    You need to perform sequential operations like slicing or sorting.
19. Why are dictionaries considered unordered, and how does that affect data retrieval?
 - Before Python 3.7, dictionaries were unordered, meaning their elements had no guaranteed sequence. In Python older versions, dictionaries preserve insertion order, but retrieval is still based on keys, not positions.
20. Explain the difference between a list and a dictionary in terms of data retrieval.
 - Lists: Retrieve elements by index position.
    l = [10, 20, 30]
    print(l[1])  # Output: 20
 - Dictionaries: Retrieve elements by key.
    d = {"a": 10, "b": 20}
    print(d["b"])  # Output: 20
1. Write a code to create a string with your name and print it?

# %%
# 1. Write a code to create a string with your name and print it?
s = str(input("Enter your name: "))
print(s)
# Out:
# Enter your name: steve
# steve

# %%
# 2. Write a code to find the length of the string "Hello World"?
s = "Hello World"
print(len(s))

# %%
# 3. Write a code to slice the first 3 characters from the string "Python Programming"?
s = "Python Programming"
new_sliced = s[:3]
print(new_sliced)

# %%
# 4. Write a code to convert the string "hello" to uppercase?
s = "Hello"
s = s.upper()
print(s)

# %%
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple"?
s = "I like apple"
new_s = s.replace("apple", "orange")
print(new_s)

# %%
# 6. Write a code to create a list with numbers 1 to 5 and print it?
l = [i for i in range(1, 6)]
print(l)

# %%
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4]?
l = [i for i in range(1, 4)]
l.append(10)
print(l)
# Out:
# [1, 2, 3, 10]

# %%
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]?
l = [i for i in range(1, 6)]
l.remove(3)
print(l)

# %%
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd']?
l = ["a", "b", "c", "d"]
print(l[1])

# %%
# 10. Write a code to reverse the list [10, 20, 30, 40, 50]?
l = [i for i in range(10, 60, 10)]
new_l = []
for i in range(len(l)-1, -1, -1):
    new_l.append(l[i])
print(new_l)

# %%
# 11. Write a code to create a tuple with the elements 10, 20, 30 and print it.
l = tuple([i for i in range(10, 60, 10)])
print(l)

# %%
# 12. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
tup = ('apple', 'banana', 'cherry')
print(tup[0])
# Out:
# apple

# %%
# 13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
tup = (1, 2, 3, 2, 4, 2)
count = 0
for i in tup:
    if i == 2:
        count += 1
print(count)

# %%
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t = ('dog', 'cat', 'rabbit')
for index, i in enumerate(t):
    if i == 'cat':
        print(index)

# %%
# 15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
tup = ('apple', 'orange', 'banana')
print('Yes' if 'banana' in tup else 'No')

# %%
# 16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
se = set([i for i in range(1,6)])
print(se)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 17. Write a code to add the element 6 to the set {1, 2, 3, 4}.
se = set([i for i in range(1,5)])
se = list(se)
se.append(6)
se = set(se)
print(se)

# %%
# 18. Write a code to create a tuple with the elements 10, 20, 30 and print it.
tup = tuple([i for i in range(10, 40, 10)])
print(tup)

# %%
# 19. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
tup = ('apple', 'banana', 'cherry')
print(tup[0])

# %%
# 20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
tup = (1, 2, 3, 2, 4, 2)
count = 0
for i in tup:
    if i == 2:
        count += 1
print(count)

# %%
# 21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t = ('dog', 'cat', 'rabbit')
for index, i in enumerate(t):
    if i == 'cat':
        print(index)

# %%
# 22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
tup = ('apple', 'orange', 'banana')
print('Yes' if 'banana' in tup else 'No')

# %%
# 23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
se = set([i for i in range(1,6)])
print(se)

# %%
# 24. Write a code to add the element 6 to the set {1, 2, 3, 4}.
se = set([i for i in range(1,5)])
se = list(se)
se.append(6)
se = set(se)
print(se)
